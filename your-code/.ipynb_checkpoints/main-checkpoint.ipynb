# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
url = "mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/stats"
engine = create_engine(url)
#engine = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/Stats')

# %% [markdown]
# #### 4. Import the users table

# %%
users = pd.read_sql_query('SELECT * FROM users', engine);
users
# Out:
#           Id  Reputation        CreationDate     DisplayName  \
# 0         -1           1 2010-07-19 06:55:26       Community
# 1          2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27          Emmett
# 4          5        6792 2010-07-19 19:03:57           Shane
# ...      ...         ...                 ...             ...
# 40320  55743           1 2014-09-13 21:03:50       AussieMeg
# 40321  55744           6 2014-09-13 21:39:30       Mia Maria
# 40322  55745         101 2014-09-13 23:45:27    tronbabylove
# 40323  55746         106 2014-09-14 00:29:41             GPP
# 40324  55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
users.rename(columns={'Id':'userId'}, inplace = True)
users
# Out:
#        userId  Reputation        CreationDate     DisplayName  \
# 0          -1           1 2010-07-19 06:55:26       Community
# 1           2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2           3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3           4         101 2010-07-19 19:03:27          Emmett
# 4           5        6792 2010-07-19 19:03:57           Shane
# ...       ...         ...                 ...             ...
# 40320   55743           1 2014-09-13 21:03:50       AussieMeg
# 40321   55744           6 2014-09-13 21:39:30       Mia Maria
# 40322   55745         101 2014-09-13 23:45:27    tronbabylove
# 40323   55746         106 2014-09-14 00:29:41             GPP
# 40324   55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
posts = pd.read_sql_query('SELECT * FROM posts', engine)

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns={'Id':'postId', 'OwnerUserId':'userId'}, inplace=True)
posts
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# ...       ...         ...               ...                 ...    ...
# 91971  115374           2               NaN 2014-09-13 23:45:39      2
# 91972  115375           1               NaN 2014-09-13 23:46:05      0
# 91973  115376           1               NaN 2014-09-14 01:27:54      1
# 91974  115377           2               NaN 2014-09-14 02:03:28      0
# 91975  115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body   userId  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
new_df_users = users[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
new_df_posts = posts[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]

print(new_df_users)
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# ...       ...         ...    ...      ...        ...
# 40320   55743           1      0        0          0
# 40321   55744           6      1        0          0
# 40322   55745         101      0        0          0
# 40323   55746         106      1        0          0
# 40324   55747           1      0        0          0
#
# [40325 rows x 5 columns]

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40325 entries, 0 to 40324
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   userId           40325 non-null  int64
#  1   Reputation       40325 non-null  int64
#  2   CreationDate     40325 non-null  datetime64[ns]
#  3   DisplayName      40325 non-null  object
#  4   LastAccessDate   40325 non-null  datetime64[ns]
#  5   WebsiteUrl       8121 non-null   object
#  6   Location         11691 non-null  object
#  7   AboutMe          9379 non-null   object
#  8   Views            40325 non-null  int64
#  9   UpVotes          40325 non-null  int64
#  10  DownVotes        40325 non-null  int64
#  11  AccountId        40325 non-null  int64
#  12  Age              8318 non-null   float64
#  13  ProfileImageUrl  16479 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(6), object(5)
# memory usage: 4.3+ MB

# %%
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91976 entries, 0 to 91975
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   postId                 91976 non-null  int64
#  1   PostTypeId             91976 non-null  int64
#  2   AcceptedAnswerId       14700 non-null  float64
#  3   CreaionDate            91976 non-null  datetime64[ns]
#  4   Score                  91976 non-null  int64
#  5   ViewCount              42921 non-null  float64
#  6   Body                   91756 non-null  object
#  7   userId                 90584 non-null  float64
#  8   LasActivityDate        91976 non-null  datetime64[ns]
#  9   Title                  42921 non-null  object
#  10  Tags                   42921 non-null  object
#  11  AnswerCount            42921 non-null  float64
#  12  CommentCount           91976 non-null  int64
#  13  FavoriteCount          13246 non-null  float64
# ...

# %%
merge_df = users.merge(posts, left_on='userId', right_on='postId')
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32057 entries, 0 to 32056
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   userId_x               32057 non-null  int64
#  1   Reputation             32057 non-null  int64
#  2   CreationDate           32057 non-null  datetime64[ns]
#  3   DisplayName            32057 non-null  object
#  4   LastAccessDate         32057 non-null  datetime64[ns]
#  5   WebsiteUrl             6740 non-null   object
#  6   Location               9546 non-null   object
#  7   AboutMe                7676 non-null   object
#  8   Views                  32057 non-null  int64
#  9   UpVotes                32057 non-null  int64
#  10  DownVotes              32057 non-null  int64
#  11  AccountId              32057 non-null  int64
#  12  Age                    6818 non-null   float64
#  13  ProfileImageUrl        11219 non-null  object
# ...

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
print(len(merge_df))
print(len(users))
print(len(posts))
# Out:
# 90584
# 40325
# 91976

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
merge_df2 = merge_df.fillna(0)
merge_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32057 entries, 0 to 32056
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   userId_x               32057 non-null  int64
#  1   Reputation             32057 non-null  int64
#  2   CreationDate           32057 non-null  datetime64[ns]
#  3   DisplayName            32057 non-null  object
#  4   LastAccessDate         32057 non-null  datetime64[ns]
#  5   WebsiteUrl             32057 non-null  object
#  6   Location               32057 non-null  object
#  7   AboutMe                32057 non-null  object
#  8   Views                  32057 non-null  int64
#  9   UpVotes                32057 non-null  int64
#  10  DownVotes              32057 non-null  int64
#  11  AccountId              32057 non-null  int64
#  12  Age                    32057 non-null  float64
#  13  ProfileImageUrl        32057 non-null  object
# ...

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
#merge_df2 = merge_df2.astype({"userId":"int32"}, errors='raise')
#merge_df2.dtypes

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.

# %%
#for i in range (len(df3)):
#    if (df3['Reputation'][i]> df3['Reputation'].mean()+2*df3['Reputation'].std()):
#        df3['Outliers'][i]='True'

#merge_df2.head(1)
outliers = merge_df2[['Reputation', 'Views', 'UpVotes', 'Score', 'ViewCount', 'AnswerCount', 'CommentCount', 'FavoriteCount']]
low = outliers.mean()-2*outliers.std()
outliers['UpVotes']
# Out:
# 0          3
# 1         19
# 2          0
# 3        662
# 4         47
#         ...
# 32052      0
# 32053      0
# 32054      0
# 32055      0
# 32056      0
# Name: UpVotes, Length: 32057, dtype: int64

# %%
outliers_list = []
for i in outliers:
    print(i)
    low = outliers[i].mean() -2*outliers[i].std();
    high = outliers[i].mean() +2*outliers[i].std();
    outliers_row = []
    for j in range(5000):
        if outliers[i][j]<low or outliers[i][j]>high:
            outliers_row.append(outliers[i][j])
    print(outliers_row)
    outliers_list.append(outliers_row)
# Out:
# Reputation
# []
# Views
# []
# UpVotes
# ...

# %%
outliers_list = []
for i in outliers:
    low = outliers[i].mean() -2*outliers[i].std();
    high = outliers[i].mean() +2*outliers[i].std();
    outliers_row = []
    for j in range(len(outliers[i])):
        if outliers[i][j]<low or outliers[i][j]>high:
            outliers_row.append(outliers[i][j])
        else:
            outliers_row.append(np.NaN)
    outliers_list.append(outliers_row)
    


outliers_df = pd.DataFrame(outliers_list)
outliers_df = outliers_df.transpose()
outliers_df.columns=['Reputation', 'Views', 'UpVotes', 'Score', 'ViewCount', 'AnswerCount', 'CommentCount', 'FavoriteCount']
outliers_df = outliers_df.dropna(how='all')

# %%
outliers_df['Reputation'].isnull().sum()
# Out:
# 1297
